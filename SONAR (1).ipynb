# %%
import re, getpass

a = getpass.getpass("paste here your encoded ... ")

while True:
    
    b = getpass.getpass("paste here your encoded ... ")
    
    if b in a:
        print (":)")
        
    else: 
        print (":(")
# Out:
# paste here your encoder song········
# ...Mn
# :(
# ...mn
# :)
